# %% [markdown]
# # Scale × Odyssey — Colab Driver
#
# This notebook is a **thin driver**: it mounts Drive (data), clones the repo (code),
# and runs the pipeline. Code lives in the GitHub repo under `src/` — not here.

# %% [markdown]
# ## 1. Mount Google Drive (data)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# ## 2. Clone (or pull) the code repo
# Set `REPO_URL` to your GitHub repo. Re-running pulls the latest.

# %%
import os
REPO_URL = 'https://github.com/<your-username>/scale-odyssey.git'  # <-- edit me
REPO_DIR = '/content/scale-odyssey'

if not os.path.isdir(REPO_DIR):
    # !git clone $REPO_URL $REPO_DIR
else:
    # !cd $REPO_DIR && git pull

# %% [markdown]
# ## 3. Install dependencies

# %%
# !pip install -r $REPO_DIR/requirements.txt --quiet

# %% [markdown]
# ## 4. Put the repo on the import path

# %%
import sys
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)

from src import data
print('data.py loaded from', data.__file__)

# %% [markdown]
# ## 5. Build the leakage-safe split
# Default folds every source into train/val/test. Pass
# `hold_out_source='nasa_lib'` to reserve the NASA imagery as an OOD test.

# %%
splits = data.prepare_splits(
    out_json='/content/drive/MyDrive/scale-odyssey/artifacts/split.json'
)

# %% [markdown]
# ## 6. (Next) transforms → model → train
# Once `src/transforms.py`, `src/model.py`, `src/train.py` exist:

# %%
# from src import transforms, model, train
# train.main(config='configs/default.yaml')
